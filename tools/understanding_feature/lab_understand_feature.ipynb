# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
feature = pickle.load(open('features.pkl', 'rb'))

# %%
feature.keys()
# Out:
# dict_keys(['aatype', 'between_segment_residues', 'domain_name', 'residue_index', 'seq_length', 'sequence', 'deletion_matrix_int', 'msa', 'num_alignments', 'msa_species_identifiers', 'template_aatype', 'template_all_atom_masks', 'template_all_atom_positions', 'template_domain_names', 'template_sequence', 'template_sum_probs'])

# %%
feature["template_aatype"].shape
# Out:
# (20, 56, 22)

# %%
plt.imshow(feature["template_aatype"].sum(axis=0))
plt.colorbar()

# %%
plt.imshow(feature["template_all_atom_masks"][0])

# %%
plt.imshow([0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
feature["template_domain_names"].shape
# Out:
# (20,)

# %%
feature["template_sum_probs"]
# Out:
# array([[54.9],
#        [54.8],
#        [54.8],
#        [54.7],
#        [54.7],
#        [54.7],
#        [54.7],
#        [54.6],
#        [54.5],
#        [54.4],
#        [54.4],
#        [54.4],
#        [54. ],
#        [54. ],
#        [53.9],
#        [53.8],
#        [53.8],
#        [53.8],
#        [48.6],
#        [45.2]], dtype=float32)
